# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# Let's start by reading in the student-mat.csv file into a pandas dataframe.

# %%
stud= pd.read_csv('student.csv')    # Read the dataset

# %%
print('Total number of students:',len(stud))
# Out:
# Total number of students: 395

# %%
stud['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
stud.info()    # Information on dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  guardian    395 non-null    object
#  11  traveltime  395 non-null    int64
#  12  studytime   395 non-null    int64
#  13  failures    395 non-null    int64
#  14  schoolsup   395 non-null    object
#  15  famsup      395 non-null    object
#  16  paid        395 non-null    object
#  17  activities  395 non-null    object
#  18  higher      395 non-null    object
#  19  internet    395 non-null    object
#  20  famrel      395 non-null    int64
#  21  freetime    395 non-null    int64
#  22  goout       395 non-null    int64
#  23  health      395 non-null    int64
#  24  absences    395 non-null    int64
#  25  G1          395 non-null    int64
#  26  G2          395 non-null    int64
#  27  G3          395 non-null    int64
# dtypes: int64(14), object(14)
# memory usage: 86.5+ KB

# %%
stud.columns    # Dataset Columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'higher', 'internet',
#        'famrel', 'freetime', 'goout', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
stud.head()    # First 5 values of dataset
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0   IPS    F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1   IPS    F   17       U     GT3       T     1     1  at_home     other  ...
# 2   IPS    F   15       U     LE3       T     1     1  at_home     other  ...
# 3   IPS    F   15       U     GT3       T     4     2   health  services  ...
# 4   IPS    F   16       U     GT3       T     3     3    other     other  ...
#
#   higher  internet  famrel  freetime goout health absences  G1  G2  G3
# 0    yes        no       4         3     4      3        6   5   6   6
# 1    yes       yes       5         3     3      3        4   5   5   6
# 2    yes       yes       4         3     2      3       10   7   8  10
# 3    yes       yes       3         2     2      5        2  15  14  15
# 4    yes        no       4         3     2      5        4   6  10  10
#
# [5 rows x 28 columns]

# %%
stud.tail()    # Last 5 values of dataset
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390    UIM   M   20       U     LE3       A     2     2  services  services
# 391    UIM   M   17       U     LE3       T     3     1  services  services
# 392    UIM   M   21       R     GT3       T     1     1     other     other
# 393    UIM   M   18       R     LE3       T     3     2  services     other
# 394    UIM   M   19       U     LE3       T     1     1     other   at_home
#
#      ... higher  internet  famrel  freetime goout health absences  G1  G2  G3
# 390  ...    yes        no       5         5     4      4       11   9   9   9
# 391  ...    yes       yes       2         4     5      2        3  14  16  16
# 392  ...    yes        no       5         5     3      3        3  10   8   7
# 393  ...    yes       yes       4         4     1      5        0  11  12  10
# 394  ...    yes       yes       3         2     3      5        5   8   9   9
#
# [5 rows x 28 columns]

# %%
stud.isnull().any()    # To check any null values present in dataset
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# higher        False
# internet      False
# famrel        False
# freetime      False
# goout         False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %% [markdown]
# - There are no null values in the given dataset

# %% [markdown]
# ## Student's Sex

# %%
f_stud = len(stud[stud['sex'] == 'F'])    # Number of female students
print('Number of female students:',f_stud)
m_stud = len(stud[stud['sex'] == 'M'])    # Number of male students
print('Number of male students:',m_stud)
# Out:
# Number of female students: 208
# Number of male students: 187

# %%
sns.set_style('whitegrid')    # male & female student representaion on countplot
sns.countplot(x='sex',data=stud,palette='plasma')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\375808890.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=stud,palette='plasma')
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# - The gender distribution is pretty even.

# %%
b = sns.kdeplot(stud['age'])    # Kernel Density Estimations
b.axes.set_title('Ages of students')
b.set_xlabel('Age')
b.set_ylabel('Count')
plt.show()

# %%
b = sns.countplot(x='age',hue='sex', data=stud, palette='inferno')
b.axes.set_title('Number of Male & Female students in different age groups')
b.set_xlabel("Age")
b.set_ylabel("Count")
plt.show()

# %% [markdown]
# - The student age seems to be ranging from 15-19, where gender distribution is pretty even in each age group.
# - The age group above 19 may be outliers, year back students or droupouts.

# %% [markdown]
# # Students from Urban & Rural Areas

# %%
u_stud = len(stud[stud['address'] == 'U'])    # Number of urban areas students
print('Number of Urban students:',u_stud)
r_stud = len(stud[stud['address'] == 'R'])    # Number of rural areas students
print('Number of Rural students:',r_stud)
# Out:
# Number of Urban students: 307
# Number of Rural students: 88

# %%
sns.set_style('whitegrid')
sns.countplot(x='address',data=stud,palette='magma')    # urban & rural representaion on countplot
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\527525476.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='address',data=stud,palette='magma')    # urban & rural representaion on countplot
# <Axes: xlabel='address', ylabel='count'>

# %% [markdown]
# - Approximately 77.72% students come from urban region and 22.28% from rural region.

# %% [markdown]
# # Age of Students

# %% [markdown]
# ### 1. Does age affect final grade?

# %%
b= sns.boxplot(x='age', y='G3',data=stud,palette='gist_heat')
b.axes.set_title('Age vs Final Grade')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\4011241504.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b= sns.boxplot(x='age', y='G3',data=stud,palette='gist_heat')
# Text(0.5, 1.0, 'Age vs Final Grade')

# %% [markdown]
# - Plotting the distribution rather than statistics would help us better understand the data.
# - The above plot shows that the median grades of the three age groups(15,16,17) are similar. Note the skewness of age group 19. (may be due to sample size). Age group 20 seems to score highest grades among all.

# %%
b = sns.swarmplot(x='age', y='G3',hue='sex', data=stud,palette='PiYG')
b.axes.set_title('Does age affect final grade?')
# Out:
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Does age affect final grade?')

# %% [markdown]
# ## 2. Do urban students perform better than rural students?

# %%
# Grade distribution by address
sns.kdeplot(stud.loc[stud['address'] == 'U', 'G3'], label='Urban', shade = True)
sns.kdeplot(stud.loc[stud['address'] == 'R', 'G3'], label='Rural', shade = True)
plt.title('Do urban students score higher than rural students?')
plt.xlabel('Grade');
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\2204101905.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stud.loc[stud['address'] == 'U', 'G3'], label='Urban', shade = True)
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\2204101905.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stud.loc[stud['address'] == 'R', 'G3'], label='Rural', shade = True)

# %% [markdown]
# - The above graph clearly shows there is not much difference between the grades based on location.

# %%
# Select only numeric columns
numeric_columns = stud.select_dtypes(include=['number'])

# Calculate the correlation with the 'G3' column and sort values
corr_values = numeric_columns.corr()['G3'].sort_values()
print(corr_values)
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# ## Encoding categorical variables using LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
stud.iloc[:,0]=le.fit_transform(stud.iloc[:,0])
stud.iloc[:,1]=le.fit_transform(stud.iloc[:,1])
stud.iloc[:,3]=le.fit_transform(stud.iloc[:,3])
stud.iloc[:,4]=le.fit_transform(stud.iloc[:,4])
stud.iloc[:,5]=le.fit_transform(stud.iloc[:,5])
stud.iloc[:,8]=le.fit_transform(stud.iloc[:,8])
stud.iloc[:,9]=le.fit_transform(stud.iloc[:,9])
stud.iloc[:,10]=le.fit_transform(stud.iloc[:,10])
stud.iloc[:,11]=le.fit_transform(stud.iloc[:,11])
stud.iloc[:,15]=le.fit_transform(stud.iloc[:,15])
stud.iloc[:,16]=le.fit_transform(stud.iloc[:,16])
stud.iloc[:,17]=le.fit_transform(stud.iloc[:,17])
stud.iloc[:,18]=le.fit_transform(stud.iloc[:,18])
stud.iloc[:,19]=le.fit_transform(stud.iloc[:,19])
stud.iloc[:,20]=le.fit_transform(stud.iloc[:,20])
stud.iloc[:,21]=le.fit_transform(stud.iloc[:,21])
stud.iloc[:,22]=le.fit_transform(stud.iloc[:,22])

# %%
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ... higher  \
# 0      0   0   18       1       0       0     4     4    0    4  ...      1
# 1      0   0   17       1       0       1     1     1    0    2  ...      1
# 2      0   0   15       1       1       1     1     1    0    2  ...      1
# 3      0   0   15       1       0       1     4     2    1    3  ...      1
# 4      0   0   16       1       0       1     3     3    2    2  ...      1
#
#    internet  famrel  freetime goout health absences  G1  G2  G3
# 0         0       3         2     3      3        6   5   6   6
# 1         1       4         2     2      3        4   5   5   6
# 2         1       3         2     1      3       10   7   8  10
# 3         1       2         1     1      5        2  15  14  15
# 4         0       3         2     1      5        4   6  10  10
#
# [5 rows x 28 columns]

# %%
stud.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ... higher  \
# 390      1   1   20       1       1       0     2     2    3    3  ...      1
# 391      1   1   17       1       1       1     3     1    3    3  ...      1
# 392      1   1   21       0       0       1     1     1    2    2  ...      1
# 393      1   1   18       0       1       1     3     2    3    2  ...      1
# 394      1   1   19       1       1       1     1     1    2    0  ...      1
#
#      internet  famrel  freetime goout health absences  G1  G2  G3
# 390         0       4         4     3      4       11   9   9   9
# 391         1       1         3     4      2        3  14  16  16
# 392         0       4         4     2      3        3  10   8   7
# 393         1       3         3     0      5        0  11  12  10
# 394         1       2         1     2      5        5   8   9   9
#
# [5 rows x 28 columns]

# %%
# Assume 'stud' is your DataFrame
# Check which columns have non-numeric values
non_numeric_cols = stud.select_dtypes(include=['object', 'bool']).columns
print(f"Non-numeric columns: {non_numeric_cols}")

# Example: Convert 'yes'/'no' to 1/0
# This will only work for columns that have 'yes'/'no' values
stud.replace({'yes': 1, 'no': 0}, inplace=True)

# Convert categorical columns to numeric (if necessary) using label encoding
from sklearn.preprocessing import LabelEncoder
for col in non_numeric_cols:
    stud[col] = LabelEncoder().fit_transform(stud[col])

# Now calculate the correlation
correlation = stud.corr()['G3'].sort_values()
print(correlation)
# Out:
# Non-numeric columns: Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'higher',
#        'internet'],
#       dtype='object')
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# schoolsup    -0.082788
# guardian     -0.070109
# health       -0.061335
# Pstatus      -0.058009
# school       -0.045017
# famsup       -0.039157
# freetime      0.011307
# activities    0.016100
# absences      0.034247
# Fjob          0.042286
# famrel        0.051363
# famsize       0.081407
# studytime     0.097820
# internet      0.098483
# paid          0.101996
# Mjob          0.102082
# sex           0.103456
# address       0.105756
# Fedu          0.152457
# higher        0.182465
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\3307955550.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stud.replace({'yes': 1, 'no': 0}, inplace=True)

# %%
# Check which columns exist in the DataFrame
columns_to_drop = ['school', 'G1', 'G2']
existing_columns_to_drop = [col for col in columns_to_drop if col in stud.columns]

# Drop only the existing columns
stud = stud.drop(existing_columns_to_drop, axis='columns')

# Print the remaining columns to confirm
print(stud.columns)
# Out:
# Index(['sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob',
#        'Fjob', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'higher', 'internet', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'G3'],
#       dtype='object')

# %% [markdown]
# - Although G1 and G2 which are period grades of a student and are highly correlated to the final grade G3, we drop them. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful because we want to find other factors affect the grade.

# %%
# Find correlations with the Grade
most_correlated = stud.corr().abs()['G3'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:9]
most_correlated
# Out:
# G3            1.000000
# failures      0.360415
# Medu          0.217147
# higher        0.182465
# age           0.161579
# Fedu          0.152457
# goout         0.132791
# traveltime    0.117142
# address       0.105756
# Name: G3, dtype: float64

# %%
stud = stud.loc[:, most_correlated.index]
stud.head()
# Out:
#    G3  failures  Medu  higher  age  Fedu  goout  traveltime  address
# 0   6         0     4       1   18     4      3           1        1
# 1   6         0     1       1   17     1      2           0        1
# 2  10         3     1       1   15     1      1           0        1
# 3  15         0     4       1   15     2      1           0        1
# 4  10         0     3       1   16     3      1           0        1

# %% [markdown]
# ### Failure Attribute

# %%
b = sns.swarmplot(x=stud['failures'],y=stud['G3'],palette='autumn')
b.axes.set_title('Previous Failures vs Final Grade(G3)')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\964533566.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.swarmplot(x=stud['failures'],y=stud['G3'],palette='autumn')
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Previous Failures vs Final Grade(G3)')
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 44.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Observation :** Student with less previous failures usually score higher

# %% [markdown]
# ### Family Education Attribute ( Fedu + Medu )

# %%
fa_edu = stud['Fedu'] + stud['Medu']
b = sns.swarmplot(x=fa_edu,y=stud['G3'],palette='summer')
b.axes.set_title('Family Education vs Final Grade(G3)')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\938285111.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.swarmplot(x=fa_edu,y=stud['G3'],palette='summer')
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Family Education vs Final Grade(G3)')

# %% [markdown]
# **Observation :** Educated families result in higher grades

# %% [markdown]
# ### Wish to go for Higher Education Attribute

# %%
b = sns.boxplot(x=stud['higher'],y=stud['G3'],palette='binary')
b.axes.set_title('Higher Education vs Final Grade(G3)')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\267693627.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.boxplot(x=stud['higher'],y=stud['G3'],palette='binary')
# Text(0.5, 1.0, 'Higher Education vs Final Grade(G3)')

# %% [markdown]
# **Observation :** Students who wish to go for higher studies score more

# %% [markdown]
# ## Going Out with Friends Attribute

# %%
b = sns.countplot(x=stud['goout'],palette='OrRd')
b.axes.set_title('Go Out vs Final Grade(G3)')
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_7008\3223993246.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.countplot(x=stud['goout'],palette='OrRd')
# Text(0.5, 1.0, 'Go Out vs Final Grade(G3)')

# %% [markdown]
# **Observation :** The students have an average score when it comes to going out with friends.

# %% [markdown]
# ### Reason Attribute

# %% [markdown]
# **Observation :** The students have an equally distributed average score when it comes to reason attribute.

# %% [markdown]
# # Machine Learning Algorithms

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
# splitting the data into training and testing data (75% and 25%)
# we mention the random state to achieve the same split everytime we run the code
X_train, X_test, y_train, y_test = train_test_split(stud, stud['G3'], test_size = 0.25, random_state=42)

# %%
X_train.head()
# Out:
#      G3  failures  Medu  higher  age  Fedu  goout  traveltime  address
# 16   14         0     4       1   16     4      2           0        1
# 66   12         0     4       1   15     4      2           0        1
# 211  13         0     4       1   17     4      4           0        1
# 7     6         0     4       1   17     4      3           1        1
# 19   10         0     4       1   16     3      2           0        1

# %% [markdown]
# ## MAE - Mean Absolute Error & RMSE - Root Mean Square Error

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))

    return mae, rmse

# %%
# find the median
median_pred = X_train['G3'].median()

# create a list with all values as median
median_preds = [median_pred for _ in range(len(X_test))]

# store the true G3 values for passing into the function
true = X_test['G3']

# %%
# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# Median Baseline  MAE: 3.7879
# Median Baseline RMSE: 4.8252

# %%
# Evaluate several ml models by training on training set and testing on testing set
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    X_train = X_train.drop('G3', axis='columns')
    X_test = X_test.drop('G3', axis='columns')
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=100)
    model4 = ExtraTreesRegressor(n_estimators=100)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=50)
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)
results
# Out:
#                             mae      rmse
# Linear Regression      3.526974  4.463865
# ElasticNet Regression  3.610609  4.576473
# Random Forest          3.688357  4.667992
# Extra Trees            3.993148  5.114271
# SVM                    3.557514   4.55179
# Gradient Boosted       3.581967  4.502147
# Baseline               3.787879  4.825228

# %%
plt.figure(figsize=(12, 7))

# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'violet', ax = ax)
plt.title('Model Mean Absolute Error') 
plt.ylabel('MAE')

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'pink', ax = ax)
plt.title('Model Root Mean Squared Error') 
plt.ylabel('RMSE')

plt.show()

# %% [markdown]
# Conclusion: As we see both Model Mean Absolute Error & Model Root Mean Squared Error that the linear regression is performing the best in both cases
